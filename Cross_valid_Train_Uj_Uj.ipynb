# %% [markdown]
# <a href="https://colab.research.google.com/github/Bitang-Melyen-Tanulok/Csip_Csip/blob/main/Cross_valid_Train_Uj_Uj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We needed to check if there is any duplication of titles or audio files among the data.
#
# If there was, we would then remove them from the database, only keeping the first appearance.

# %%
import os
import numpy as np
import pandas as pd
import librosa
import tensorflow_hub as hub
from tensorflow.keras.preprocessing import image
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')
base_path = '/content/drive/MyDrive/DeepLearning'
spectrograms_path = os.path.join(base_path, 'ugyanaz?')  # Directory for spectrogram files

import hashlib
import shutil

import os
import hashlib

X = []
Y = []

def get_file_hash(file_path):
    hash_md5 = hashlib.md5()  # Create an MD5 hash object to store the file's hash value
    with open(file_path, "rb") as f:
        # Read the file in chunks (4KB at a time) and update the hash
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()  # Return the final hash value as a hexadecimal string

def delete_duplicates_and_log(spectrograms_path):
    global X,Y
    seen_hashes = set()  # This will store the hashes of files we've already processed
    files_to_delete = []  # List to track files that are duplicates and will be deleted
    files_to_keep = []  # List to track files that are unique and will be kept

    # Walk through the folders in the spectrograms directory
    for folder in os.listdir(spectrograms_path):
        folder_path = os.path.join(spectrograms_path, folder)

        # Loop through the files in the current folder
        files = os.listdir(folder_path)
        for file in files:
            if file.endswith('.png'):  # We're only interested in .png files (spectrograms)
                file_path = os.path.join(folder_path, file)

                # Generate a hash for the file to compare it with others
                file_hash = get_file_hash(file_path)

                if file_hash in seen_hashes:
                    # If we've already seen this hash, it's a duplicate
                    #print(f"Duplicate file found: {file_path}")
                    files_to_delete.append(file_path)
                else:
                    # If we haven't seen this hash yet, add it to the seen set and keep it
                    seen_hashes.add(file_hash)
                    files_to_keep.append(file_path)

                    img = image.load_img(file_path, color_mode="rgb")
                    img_array = image.img_to_array(img)
                    X.append(img_array)
                    Y.append(folder)

    # Log files that we kept (not duplicates)
    '''
    print("Files kept:")
    for file_path in files_to_keep:
        print(f"   - Keeping file: {file_path}")
    '''

    # Log files that we deleted (duplicates)
    print("\nFiles deleted:")
    for file_path in files_to_delete:
        print(f"   - Deleting file: {file_path}")
        os.remove(file_path)  # Actually delete the duplicate files

    # Convert X and Y to numpy arrays
    X = np.array(X)
    Y = np.array(Y)

    # Shuffle the data
    permutation = np.random.permutation(len(X))
    X = X[permutation]
    Y = Y[permutation]

    # Print shapes of the arrays
    print(f"\nX shape: {X.shape}")
    print(f"Y shape: {Y.shape}")

    return X, Y

X, Y = delete_duplicates_and_log(spectrograms_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Files deleted:
#
# X shape: (1769, 128, 313, 3)
# Y shape: (1769,)

# %% [markdown]
# Since this is a multi-class classification task, I am converting labels to one-hot format:

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

#First, the labels need to be converted into numerical values
le = LabelEncoder()
Y_encoded = le.fit_transform(Y)

#Getting number of classes
num_classes = len(le.classes_)
print(f"Class number= {num_classes}")

#Converting to one-hot encoding
Y_onehot = to_categorical(Y_encoded, num_classes)
# Out:
# Class number= 20

# %% [markdown]
# We implemented early stopping, in case the model started overfitting.

# %%
from tensorflow.keras.callbacks import EarlyStopping

#Implementing early stopping, since there is no reason for it to learn further when val_loss isn't decreasing
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5, #If it doesn't improve for 10 epochs, it concludes
    verbose=1,
    restore_best_weights=True
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint # Importing the missing ModelCheckpoint class

#Wanting to save the best model, so implementing checkpointing
checkpoint = ModelCheckpoint(
    'best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# %%
# !pip install efficientnet
# Out:
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.25.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %% [markdown]
# We used efficientNetV2 pretrained model, since most kaggle teams suggested it.

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# Setting up Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_accuracies = []
fold_losses = []
history_per_fold = []

# Starting K-Fold
fold_number = 1
for train_index, valid_index in skf.split(X, Y_encoded):
    print(f"Starting fold: {fold_number}")

    # Splitting the data into training and validation sets
    X_train, X_valid = X[train_index], X[valid_index]
    Y_train, Y_valid = Y_onehot[train_index], Y_onehot[valid_index]

    # Normalizing the data
    X_train = preprocess_input(X_train) #X_train = X_train / np.max(X_train)
    X_valid = preprocess_input(X_valid) #X_valid = X_valid / np.max(X_valid)

    # Setting the input shape based on the data
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Loading the pre-trained EfficientNetV2B0 model
    base_model = EfficientNetV2B0(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape
    )

    # Defining a new model
    model = models.Sequential()

    # Freezing the base model layers if we don't want to update them during training
    base_model.trainable = False

    # Adding the pre-trained model
    model.add(base_model)
    model.add(layers.GlobalAveragePooling2D())  # Selecting the best representations

    # Adding Dense layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))  # Adding Dropout to prevent overfitting
    model.add(layers.Dense(num_classes, activation='softmax'))  # Output layer


    # Compiling the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Training the model
    history = model.fit(
        X_train, Y_train,
        epochs=100,
        batch_size=64,
        validation_data=(X_valid, Y_valid),
        callbacks=[early_stopping, checkpoint],
        verbose=1
    )

    # Saving the results
    history_per_fold.append(history)
    valid_loss, valid_accuracy = model.evaluate(X_valid, Y_valid)

    fold_accuracies.append(valid_accuracy)
    fold_losses.append(valid_loss)

    fold_number += 1

# Summary of the final model
model.summary()
# Out:
# Starting fold: 1
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 2.1110 - accuracy: 0.3873
# Epoch 1: val_loss improved from inf to 1.57527, saving model to best_model.keras
# 45/45 [==============================] - 104s 2s/step - loss: 2.1110 - accuracy: 0.3873 - val_loss: 1.5753 - val_accuracy: 0.5593
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.6206 - accuracy: 0.5357
# Epoch 2: val_loss improved from 1.57527 to 1.35990, saving model to best_model.keras
# 45/45 [==============================] - 93s 2s/step - loss: 1.6206 - accuracy: 0.5357 - val_loss: 1.3599 - val_accuracy: 0.6130
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.4202 - accuracy: 0.5809
# Epoch 3: val_loss improved from 1.35990 to 1.28487, saving model to best_model.keras
# 45/45 [==============================] - 90s 2s/step - loss: 1.4202 - accuracy: 0.5809 - val_loss: 1.2849 - val_accuracy: 0.6441
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.3297 - accuracy: 0.6042
# Epoch 4: val_loss improved from 1.28487 to 1.17905, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 1.3297 - accuracy: 0.6042 - val_loss: 1.1790 - val_accuracy: 0.6751
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2565 - accuracy: 0.6332
# Epoch 5: val_loss improved from 1.17905 to 1.12933, saving model to best_model.keras
# 45/45 [==============================] - 91s 2s/step - loss: 1.2565 - accuracy: 0.6332 - val_loss: 1.1293 - val_accuracy: 0.6638
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1665 - accuracy: 0.6615
# Epoch 6: val_loss improved from 1.12933 to 1.08857, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 1.1665 - accuracy: 0.6615 - val_loss: 1.0886 - val_accuracy: 0.6695
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1003 - accuracy: 0.6770
# Epoch 7: val_loss improved from 1.08857 to 1.03862, saving model to best_model.keras
# 45/45 [==============================] - 94s 2s/step - loss: 1.1003 - accuracy: 0.6770 - val_loss: 1.0386 - val_accuracy: 0.6751
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0367 - accuracy: 0.7004
# Epoch 8: val_loss improved from 1.03862 to 1.01711, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 1.0367 - accuracy: 0.7004 - val_loss: 1.0171 - val_accuracy: 0.6921
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0066 - accuracy: 0.7067
# Epoch 9: val_loss improved from 1.01711 to 0.99541, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 1.0066 - accuracy: 0.7067 - val_loss: 0.9954 - val_accuracy: 0.6977
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9448 - accuracy: 0.7110
# Epoch 10: val_loss improved from 0.99541 to 0.96583, saving model to best_model.keras
# 45/45 [==============================] - 94s 2s/step - loss: 0.9448 - accuracy: 0.7110 - val_loss: 0.9658 - val_accuracy: 0.7175
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.7272
# Epoch 11: val_loss improved from 0.96583 to 0.94329, saving model to best_model.keras
# 45/45 [==============================] - 93s 2s/step - loss: 0.9295 - accuracy: 0.7272 - val_loss: 0.9433 - val_accuracy: 0.7006
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8882 - accuracy: 0.7223
# Epoch 12: val_loss improved from 0.94329 to 0.93538, saving model to best_model.keras
# 45/45 [==============================] - 95s 2s/step - loss: 0.8882 - accuracy: 0.7223 - val_loss: 0.9354 - val_accuracy: 0.7175
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8560 - accuracy: 0.7385
# Epoch 13: val_loss did not improve from 0.93538
# 45/45 [==============================] - 92s 2s/step - loss: 0.8560 - accuracy: 0.7385 - val_loss: 0.9388 - val_accuracy: 0.7203
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8558 - accuracy: 0.7378
# Epoch 14: val_loss improved from 0.93538 to 0.92455, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 0.8558 - accuracy: 0.7378 - val_loss: 0.9245 - val_accuracy: 0.7345
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7922 - accuracy: 0.7661
# Epoch 15: val_loss improved from 0.92455 to 0.89496, saving model to best_model.keras
# 45/45 [==============================] - 91s 2s/step - loss: 0.7922 - accuracy: 0.7661 - val_loss: 0.8950 - val_accuracy: 0.7429
# Epoch 16/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7268 - accuracy: 0.7625
# Epoch 16: val_loss did not improve from 0.89496
# 45/45 [==============================] - 90s 2s/step - loss: 0.7268 - accuracy: 0.7625 - val_loss: 0.8973 - val_accuracy: 0.7147
# Epoch 17/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.7668
# Epoch 17: val_loss did not improve from 0.89496
# 45/45 [==============================] - 90s 2s/step - loss: 0.7437 - accuracy: 0.7668 - val_loss: 0.9200 - val_accuracy: 0.7006
# Epoch 18/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.7739
# Epoch 18: val_loss improved from 0.89496 to 0.84312, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 0.7205 - accuracy: 0.7739 - val_loss: 0.8431 - val_accuracy: 0.7514
# Epoch 19/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.7922
# Epoch 19: val_loss did not improve from 0.84312
# 45/45 [==============================] - 89s 2s/step - loss: 0.6904 - accuracy: 0.7922 - val_loss: 0.8679 - val_accuracy: 0.7373
# Epoch 20/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6864 - accuracy: 0.7866
# Epoch 20: val_loss did not improve from 0.84312
# 45/45 [==============================] - 90s 2s/step - loss: 0.6864 - accuracy: 0.7866 - val_loss: 0.8495 - val_accuracy: 0.7429
# Epoch 21/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.8014
# Epoch 21: val_loss did not improve from 0.84312
# 45/45 [==============================] - 91s 2s/step - loss: 0.6333 - accuracy: 0.8014 - val_loss: 0.8440 - val_accuracy: 0.7401
# Epoch 22/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.8007
# Epoch 22: val_loss improved from 0.84312 to 0.82708, saving model to best_model.keras
# 45/45 [==============================] - 90s 2s/step - loss: 0.6227 - accuracy: 0.8007 - val_loss: 0.8271 - val_accuracy: 0.7514
# Epoch 23/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.8113
# Epoch 23: val_loss did not improve from 0.82708
# 45/45 [==============================] - 89s 2s/step - loss: 0.6124 - accuracy: 0.8113 - val_loss: 0.8517 - val_accuracy: 0.7345
# Epoch 24/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.7986
# Epoch 24: val_loss did not improve from 0.82708
# 45/45 [==============================] - 88s 2s/step - loss: 0.6137 - accuracy: 0.7986 - val_loss: 0.8588 - val_accuracy: 0.7373
# Epoch 25/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.8177
# Epoch 25: val_loss did not improve from 0.82708
# 45/45 [==============================] - 89s 2s/step - loss: 0.5854 - accuracy: 0.8177 - val_loss: 0.8478 - val_accuracy: 0.7373
# Epoch 26/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5572 - accuracy: 0.8191
# Epoch 26: val_loss did not improve from 0.82708
# 45/45 [==============================] - 90s 2s/step - loss: 0.5572 - accuracy: 0.8191 - val_loss: 0.8456 - val_accuracy: 0.7401
# Epoch 27/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5316 - accuracy: 0.8339
# Epoch 27: val_loss improved from 0.82708 to 0.80420, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 0.5316 - accuracy: 0.8339 - val_loss: 0.8042 - val_accuracy: 0.7514
# Epoch 28/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5105 - accuracy: 0.8473
# Epoch 28: val_loss did not improve from 0.80420
# 45/45 [==============================] - 90s 2s/step - loss: 0.5105 - accuracy: 0.8473 - val_loss: 0.8202 - val_accuracy: 0.7429
# Epoch 29/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5231 - accuracy: 0.8431
# Epoch 29: val_loss improved from 0.80420 to 0.80155, saving model to best_model.keras
# 45/45 [==============================] - 92s 2s/step - loss: 0.5231 - accuracy: 0.8431 - val_loss: 0.8016 - val_accuracy: 0.7627
# Epoch 30/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5099 - accuracy: 0.8382
# Epoch 30: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.5099 - accuracy: 0.8382 - val_loss: 0.8491 - val_accuracy: 0.7458
# Epoch 31/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4658 - accuracy: 0.8551
# Epoch 31: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.4658 - accuracy: 0.8551 - val_loss: 0.8433 - val_accuracy: 0.7514
# Epoch 32/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.8445
# Epoch 32: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.4904 - accuracy: 0.8445 - val_loss: 0.8224 - val_accuracy: 0.7571
# Epoch 33/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8558
# Epoch 33: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.4800 - accuracy: 0.8558 - val_loss: 0.8153 - val_accuracy: 0.7514
# Epoch 34/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.8523Restoring model weights from the end of the best epoch: 29.
#
# Epoch 34: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4578 - accuracy: 0.8523 - val_loss: 0.8542 - val_accuracy: 0.7486
# Epoch 34: early stopping
# 12/12 [==============================] - 18s 1s/step - loss: 0.8016 - accuracy: 0.7627
# Starting fold: 2
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 2.0770 - accuracy: 0.4141
# Epoch 1: val_loss did not improve from 0.80155
# 45/45 [==============================] - 104s 2s/step - loss: 2.0770 - accuracy: 0.4141 - val_loss: 1.6977 - val_accuracy: 0.5226
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.6031 - accuracy: 0.5470
# Epoch 2: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 1.6031 - accuracy: 0.5470 - val_loss: 1.4896 - val_accuracy: 0.5621
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.4324 - accuracy: 0.5922
# Epoch 3: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.4324 - accuracy: 0.5922 - val_loss: 1.3560 - val_accuracy: 0.6215
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2784 - accuracy: 0.6297
# Epoch 4: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.2784 - accuracy: 0.6297 - val_loss: 1.2469 - val_accuracy: 0.6243
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2237 - accuracy: 0.6382
# Epoch 5: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 1.2237 - accuracy: 0.6382 - val_loss: 1.2019 - val_accuracy: 0.6497
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1400 - accuracy: 0.6735
# Epoch 6: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 1.1400 - accuracy: 0.6735 - val_loss: 1.1423 - val_accuracy: 0.6525
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1039 - accuracy: 0.6799
# Epoch 7: val_loss did not improve from 0.80155
# 45/45 [==============================] - 93s 2s/step - loss: 1.1039 - accuracy: 0.6799 - val_loss: 1.1255 - val_accuracy: 0.6582
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0461 - accuracy: 0.6848
# Epoch 8: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.0461 - accuracy: 0.6848 - val_loss: 1.1514 - val_accuracy: 0.6554
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9998 - accuracy: 0.7011
# Epoch 9: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.9998 - accuracy: 0.7011 - val_loss: 1.0815 - val_accuracy: 0.6610
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9149 - accuracy: 0.7272
# Epoch 10: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.9149 - accuracy: 0.7272 - val_loss: 1.0719 - val_accuracy: 0.6723
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9248 - accuracy: 0.7124
# Epoch 11: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.9248 - accuracy: 0.7124 - val_loss: 1.0363 - val_accuracy: 0.6780
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8422 - accuracy: 0.7442
# Epoch 12: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.8422 - accuracy: 0.7442 - val_loss: 0.9778 - val_accuracy: 0.6836
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8464 - accuracy: 0.7392
# Epoch 13: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.8464 - accuracy: 0.7392 - val_loss: 0.9929 - val_accuracy: 0.7034
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8357 - accuracy: 0.7442
# Epoch 14: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.8357 - accuracy: 0.7442 - val_loss: 0.9600 - val_accuracy: 0.7062
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7825 - accuracy: 0.7534
# Epoch 15: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.7825 - accuracy: 0.7534 - val_loss: 0.9639 - val_accuracy: 0.6977
# Epoch 16/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7677 - accuracy: 0.7625
# Epoch 16: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.7677 - accuracy: 0.7625 - val_loss: 0.9628 - val_accuracy: 0.7090
# Epoch 17/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7543 - accuracy: 0.7682
# Epoch 17: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.7543 - accuracy: 0.7682 - val_loss: 0.9664 - val_accuracy: 0.7062
# Epoch 18/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7274 - accuracy: 0.7795
# Epoch 18: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.7274 - accuracy: 0.7795 - val_loss: 0.9775 - val_accuracy: 0.7090
# Epoch 19/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6918 - accuracy: 0.7873
# Epoch 19: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6918 - accuracy: 0.7873 - val_loss: 0.9480 - val_accuracy: 0.7119
# Epoch 20/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.7887
# Epoch 20: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.6927 - accuracy: 0.7887 - val_loss: 0.9162 - val_accuracy: 0.7316
# Epoch 21/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.7915
# Epoch 21: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6460 - accuracy: 0.7915 - val_loss: 0.9434 - val_accuracy: 0.7119
# Epoch 22/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6531 - accuracy: 0.7979
# Epoch 22: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.6531 - accuracy: 0.7979 - val_loss: 0.8781 - val_accuracy: 0.7260
# Epoch 23/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.7887
# Epoch 23: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.6447 - accuracy: 0.7887 - val_loss: 0.8921 - val_accuracy: 0.7288
# Epoch 24/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.8099
# Epoch 24: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.6024 - accuracy: 0.8099 - val_loss: 0.8977 - val_accuracy: 0.7203
# Epoch 25/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5576 - accuracy: 0.8410
# Epoch 25: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5576 - accuracy: 0.8410 - val_loss: 0.9426 - val_accuracy: 0.7175
# Epoch 26/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.8177
# Epoch 26: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5740 - accuracy: 0.8177 - val_loss: 0.8606 - val_accuracy: 0.7486
# Epoch 27/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.8339
# Epoch 27: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.5334 - accuracy: 0.8339 - val_loss: 0.8934 - val_accuracy: 0.7401
# Epoch 28/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5417 - accuracy: 0.8389
# Epoch 28: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.5417 - accuracy: 0.8389 - val_loss: 0.8962 - val_accuracy: 0.7175
# Epoch 29/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.8375
# Epoch 29: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.5125 - accuracy: 0.8375 - val_loss: 0.8807 - val_accuracy: 0.7345
# Epoch 30/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.8304
# Epoch 30: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.5275 - accuracy: 0.8304 - val_loss: 0.8923 - val_accuracy: 0.7288
# Epoch 31/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4959 - accuracy: 0.8417Restoring model weights from the end of the best epoch: 26.
#
# Epoch 31: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.4959 - accuracy: 0.8417 - val_loss: 0.8990 - val_accuracy: 0.7316
# Epoch 31: early stopping
# 12/12 [==============================] - 17s 1s/step - loss: 0.8606 - accuracy: 0.7486
# Starting fold: 3
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 2.0794 - accuracy: 0.3929
# Epoch 1: val_loss did not improve from 0.80155
# 45/45 [==============================] - 102s 2s/step - loss: 2.0794 - accuracy: 0.3929 - val_loss: 1.5274 - val_accuracy: 0.5650
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.5839 - accuracy: 0.5392
# Epoch 2: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.5839 - accuracy: 0.5392 - val_loss: 1.3165 - val_accuracy: 0.6186
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.3896 - accuracy: 0.5979
# Epoch 3: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.3896 - accuracy: 0.5979 - val_loss: 1.2240 - val_accuracy: 0.6441
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2670 - accuracy: 0.6269
# Epoch 4: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 1.2670 - accuracy: 0.6269 - val_loss: 1.1222 - val_accuracy: 0.6751
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1678 - accuracy: 0.6636
# Epoch 5: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 1.1678 - accuracy: 0.6636 - val_loss: 1.0768 - val_accuracy: 0.6638
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1093 - accuracy: 0.6721
# Epoch 6: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.1093 - accuracy: 0.6721 - val_loss: 1.0282 - val_accuracy: 0.6977
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0581 - accuracy: 0.6756
# Epoch 7: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 1.0581 - accuracy: 0.6756 - val_loss: 1.0429 - val_accuracy: 0.6780
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9860 - accuracy: 0.7011
# Epoch 8: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 0.9860 - accuracy: 0.7011 - val_loss: 0.9739 - val_accuracy: 0.7203
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9575 - accuracy: 0.7053
# Epoch 9: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.9575 - accuracy: 0.7053 - val_loss: 0.9932 - val_accuracy: 0.7147
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9092 - accuracy: 0.7329
# Epoch 10: val_loss did not improve from 0.80155
# 45/45 [==============================] - 92s 2s/step - loss: 0.9092 - accuracy: 0.7329 - val_loss: 0.9367 - val_accuracy: 0.7147
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8478 - accuracy: 0.7463
# Epoch 11: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.8478 - accuracy: 0.7463 - val_loss: 0.9182 - val_accuracy: 0.7571
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8360 - accuracy: 0.7442
# Epoch 12: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.8360 - accuracy: 0.7442 - val_loss: 0.9369 - val_accuracy: 0.7345
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8141 - accuracy: 0.7534
# Epoch 13: val_loss did not improve from 0.80155
# 45/45 [==============================] - 92s 2s/step - loss: 0.8141 - accuracy: 0.7534 - val_loss: 0.9306 - val_accuracy: 0.7401
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7644 - accuracy: 0.7640
# Epoch 14: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.7644 - accuracy: 0.7640 - val_loss: 0.9086 - val_accuracy: 0.7486
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7268 - accuracy: 0.7618
# Epoch 15: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.7268 - accuracy: 0.7618 - val_loss: 0.8663 - val_accuracy: 0.7599
# Epoch 16/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.7873
# Epoch 16: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 0.7074 - accuracy: 0.7873 - val_loss: 0.9042 - val_accuracy: 0.7486
# Epoch 17/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.7887
# Epoch 17: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6822 - accuracy: 0.7887 - val_loss: 0.8740 - val_accuracy: 0.7345
# Epoch 18/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.7887
# Epoch 18: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6626 - accuracy: 0.7887 - val_loss: 0.8648 - val_accuracy: 0.7599
# Epoch 19/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6724 - accuracy: 0.7845
# Epoch 19: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.6724 - accuracy: 0.7845 - val_loss: 0.8456 - val_accuracy: 0.7655
# Epoch 20/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6507 - accuracy: 0.8057
# Epoch 20: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6507 - accuracy: 0.8057 - val_loss: 0.8485 - val_accuracy: 0.7571
# Epoch 21/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5884 - accuracy: 0.8261
# Epoch 21: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.5884 - accuracy: 0.8261 - val_loss: 0.8532 - val_accuracy: 0.7599
# Epoch 22/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5944 - accuracy: 0.8212
# Epoch 22: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.5944 - accuracy: 0.8212 - val_loss: 0.8457 - val_accuracy: 0.7599
# Epoch 23/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.8120
# Epoch 23: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.5756 - accuracy: 0.8120 - val_loss: 0.8315 - val_accuracy: 0.7655
# Epoch 24/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.8389
# Epoch 24: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5459 - accuracy: 0.8389 - val_loss: 0.8414 - val_accuracy: 0.7684
# Epoch 25/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.8269
# Epoch 25: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5548 - accuracy: 0.8269 - val_loss: 0.8376 - val_accuracy: 0.7825
# Epoch 26/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.8297
# Epoch 26: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5189 - accuracy: 0.8297 - val_loss: 0.8200 - val_accuracy: 0.7684
# Epoch 27/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.8396
# Epoch 27: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4989 - accuracy: 0.8396 - val_loss: 0.8442 - val_accuracy: 0.7740
# Epoch 28/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8523
# Epoch 28: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4654 - accuracy: 0.8523 - val_loss: 0.8423 - val_accuracy: 0.7740
# Epoch 29/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4560 - accuracy: 0.8544
# Epoch 29: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4560 - accuracy: 0.8544 - val_loss: 0.8407 - val_accuracy: 0.7655
# Epoch 30/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4459 - accuracy: 0.8558
# Epoch 30: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4459 - accuracy: 0.8558 - val_loss: 0.8645 - val_accuracy: 0.7825
# Epoch 31/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4220 - accuracy: 0.8678Restoring model weights from the end of the best epoch: 26.
#
# Epoch 31: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4220 - accuracy: 0.8678 - val_loss: 0.8207 - val_accuracy: 0.7853
# Epoch 31: early stopping
# 12/12 [==============================] - 18s 1s/step - loss: 0.8200 - accuracy: 0.7684
# Starting fold: 4
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 2.0762 - accuracy: 0.4071
# Epoch 1: val_loss did not improve from 0.80155
# 45/45 [==============================] - 101s 2s/step - loss: 2.0762 - accuracy: 0.4071 - val_loss: 1.5578 - val_accuracy: 0.5480
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.5767 - accuracy: 0.5597
# Epoch 2: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 1.5767 - accuracy: 0.5597 - val_loss: 1.3794 - val_accuracy: 0.5989
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.3879 - accuracy: 0.6007
# Epoch 3: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 1.3879 - accuracy: 0.6007 - val_loss: 1.3041 - val_accuracy: 0.5989
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2688 - accuracy: 0.6283
# Epoch 4: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 1.2688 - accuracy: 0.6283 - val_loss: 1.2306 - val_accuracy: 0.6328
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.1772 - accuracy: 0.6551
# Epoch 5: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 1.1772 - accuracy: 0.6551 - val_loss: 1.1900 - val_accuracy: 0.6441
# Epoch 6/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.6707
# Epoch 6: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 1.0986 - accuracy: 0.6707 - val_loss: 1.1299 - val_accuracy: 0.6638
# Epoch 7/100
# 45/45 [==============================] - ETA: 0s - loss: 1.0124 - accuracy: 0.6954
# Epoch 7: val_loss did not improve from 0.80155
# 45/45 [==============================] - 87s 2s/step - loss: 1.0124 - accuracy: 0.6954 - val_loss: 1.1110 - val_accuracy: 0.6638
# Epoch 8/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9983 - accuracy: 0.6862
# Epoch 8: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.9983 - accuracy: 0.6862 - val_loss: 1.1005 - val_accuracy: 0.6638
# Epoch 9/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9456 - accuracy: 0.7138
# Epoch 9: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.9456 - accuracy: 0.7138 - val_loss: 1.0441 - val_accuracy: 0.6808
# Epoch 10/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9180 - accuracy: 0.7230
# Epoch 10: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.9180 - accuracy: 0.7230 - val_loss: 1.0391 - val_accuracy: 0.6921
# Epoch 11/100
# 45/45 [==============================] - ETA: 0s - loss: 0.9108 - accuracy: 0.7216
# Epoch 11: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.9108 - accuracy: 0.7216 - val_loss: 1.0450 - val_accuracy: 0.6780
# Epoch 12/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8267 - accuracy: 0.7406
# Epoch 12: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.8267 - accuracy: 0.7406 - val_loss: 1.0468 - val_accuracy: 0.6949
# Epoch 13/100
# 45/45 [==============================] - ETA: 0s - loss: 0.8213 - accuracy: 0.7477
# Epoch 13: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.8213 - accuracy: 0.7477 - val_loss: 1.0132 - val_accuracy: 0.7034
# Epoch 14/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7897 - accuracy: 0.7477
# Epoch 14: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.7897 - accuracy: 0.7477 - val_loss: 0.9997 - val_accuracy: 0.7062
# Epoch 15/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.7668
# Epoch 15: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.7441 - accuracy: 0.7668 - val_loss: 0.9897 - val_accuracy: 0.6949
# Epoch 16/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7402 - accuracy: 0.7781
# Epoch 16: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.7402 - accuracy: 0.7781 - val_loss: 0.9828 - val_accuracy: 0.7119
# Epoch 17/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6715 - accuracy: 0.7837
# Epoch 17: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.6715 - accuracy: 0.7837 - val_loss: 1.0876 - val_accuracy: 0.6695
# Epoch 18/100
# 45/45 [==============================] - ETA: 0s - loss: 0.7067 - accuracy: 0.7668
# Epoch 18: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.7067 - accuracy: 0.7668 - val_loss: 1.0002 - val_accuracy: 0.6949
# Epoch 19/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.7915
# Epoch 19: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6637 - accuracy: 0.7915 - val_loss: 1.0515 - val_accuracy: 0.6893
# Epoch 20/100
# 45/45 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.8028
# Epoch 20: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.6270 - accuracy: 0.8028 - val_loss: 0.9612 - val_accuracy: 0.7203
# Epoch 21/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5782 - accuracy: 0.8261
# Epoch 21: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.5782 - accuracy: 0.8261 - val_loss: 0.9853 - val_accuracy: 0.7175
# Epoch 22/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5915 - accuracy: 0.8099
# Epoch 22: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.5915 - accuracy: 0.8099 - val_loss: 0.9585 - val_accuracy: 0.7175
# Epoch 23/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5744 - accuracy: 0.8212
# Epoch 23: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5744 - accuracy: 0.8212 - val_loss: 0.9415 - val_accuracy: 0.7345
# Epoch 24/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.8191
# Epoch 24: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5629 - accuracy: 0.8191 - val_loss: 0.9504 - val_accuracy: 0.7316
# Epoch 25/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5568 - accuracy: 0.8191
# Epoch 25: val_loss did not improve from 0.80155
# 45/45 [==============================] - 90s 2s/step - loss: 0.5568 - accuracy: 0.8191 - val_loss: 1.0069 - val_accuracy: 0.7062
# Epoch 26/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.8353
# Epoch 26: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5293 - accuracy: 0.8353 - val_loss: 0.9518 - val_accuracy: 0.7260
# Epoch 27/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.8318
# Epoch 27: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5469 - accuracy: 0.8318 - val_loss: 0.9276 - val_accuracy: 0.7429
# Epoch 28/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5184 - accuracy: 0.8283
# Epoch 28: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.5184 - accuracy: 0.8283 - val_loss: 0.9223 - val_accuracy: 0.7345
# Epoch 29/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.8438
# Epoch 29: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.4776 - accuracy: 0.8438 - val_loss: 0.9893 - val_accuracy: 0.7260
# Epoch 30/100
# 45/45 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.8459
# Epoch 30: val_loss did not improve from 0.80155
# 45/45 [==============================] - 89s 2s/step - loss: 0.5128 - accuracy: 0.8459 - val_loss: 0.9814 - val_accuracy: 0.7232
# Epoch 31/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8481
# Epoch 31: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.4726 - accuracy: 0.8481 - val_loss: 1.0489 - val_accuracy: 0.7345
# Epoch 32/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.8558
# Epoch 32: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.4428 - accuracy: 0.8558 - val_loss: 0.9728 - val_accuracy: 0.7288
# Epoch 33/100
# 45/45 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.8714Restoring model weights from the end of the best epoch: 28.
#
# Epoch 33: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 0.4402 - accuracy: 0.8714 - val_loss: 0.9495 - val_accuracy: 0.7401
# Epoch 33: early stopping
# 12/12 [==============================] - 18s 1s/step - loss: 0.9223 - accuracy: 0.7345
# Starting fold: 5
# Epoch 1/100
# 45/45 [==============================] - ETA: 0s - loss: 2.1086 - accuracy: 0.4082
# Epoch 1: val_loss did not improve from 0.80155
# 45/45 [==============================] - 103s 2s/step - loss: 2.1086 - accuracy: 0.4082 - val_loss: 1.6526 - val_accuracy: 0.5156
# Epoch 2/100
# 45/45 [==============================] - ETA: 0s - loss: 1.6356 - accuracy: 0.5261
# Epoch 2: val_loss did not improve from 0.80155
# 45/45 [==============================] - 91s 2s/step - loss: 1.6356 - accuracy: 0.5261 - val_loss: 1.3925 - val_accuracy: 0.5807
# Epoch 3/100
# 45/45 [==============================] - ETA: 0s - loss: 1.4134 - accuracy: 0.5855
# Epoch 3: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 1.4134 - accuracy: 0.5855 - val_loss: 1.3409 - val_accuracy: 0.6147
# Epoch 4/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2779 - accuracy: 0.6285
# Epoch 4: val_loss did not improve from 0.80155
# 45/45 [==============================] - 88s 2s/step - loss: 1.2779 - accuracy: 0.6285 - val_loss: 1.2324 - val_accuracy: 0.6516
# Epoch 5/100
# 45/45 [==============================] - ETA: 0s - loss: 1.2081 - accuracy: 0.6561

# %%
print("\nCross-Validation Results:")
print(f"Mean Validation Loss: {np.mean(fold_losses)}")
print(f"Mean Validation Accuracy: {np.mean(fold_accuracies)}")

for i, (loss, accuracy) in enumerate(zip(fold_losses, fold_accuracies), start=1):
    print(f"Fold {i} - Validation Loss: {loss}, Validation Accuracy: {accuracy}")

# %%
import matplotlib.pyplot as plt

# Plot loss and accuracy for each fold
for i, history in enumerate(history_per_fold):
  plt.figure(figsize=(12, 6))

  # Plot accuracy
  plt.subplot(1, 2, 1)
  plt.plot(history.history['accuracy'], label='Training Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.title(f'Fold {i + 1} Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()

  # Plot loss
  plt.subplot(1, 2, 2)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title(f'Fold {i + 1} Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()

  plt.tight_layout()
  plt.show()
